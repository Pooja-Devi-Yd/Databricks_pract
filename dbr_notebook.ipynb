-- %%
%python
print(1+1)

def write_delta_table(df, table_name):
    """
    Writes a DataFrame as a Delta table.

    Parameters:
        df         : PySpark DataFrame
        table_name : Target Unity Catalog table name
    """
    
    df.write \
        .format("delta") \
        .mode("overwrite") \
        .option("delta.columnMapping.mode", "name") \
        .saveAsTable(table_name)

-- %%
%python
df = spark.read.table("dev.bronze.invoice_data")
display(df)

-- %%
%python
from pyspark.sql.functions import sum
df1 = df.groupBy("JOINING_DATE").agg(sum("Salary"))

-- %%
%python
display(df1)
